# %%
# Composed of agents

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
eyes = [2.25,3.75,5,5,4] 
nose = [3,3,6]
mouth = [2.5,3,3.5, 1.15,1,1.15,8]
target_gene = np.array(eyes + nose + mouth)

# %%
target_gene
# Out:
# array([2.25, 3.75, 5.  , 5.  , 4.  , 3.  , 3.  , 6.  , 2.5 , 3.  , 3.5 ,
#        1.15, 1.  , 1.15, 8.  ])

# %%
def draw_face(target):
    plt.plot([target[0],target[1]], [target[2],target[3]], 'go', markersize=target[4]*10)
    plt.plot(target[5], target[6], 'r^', markersize=target[7]*10)
    plt.plot([target[8],target[9],target[10]], [target[11],target[12],target[13]], 'b', linewidth=target[14])
    plt.tight_layout()

# %%
draw_face(target_gene)

# %% [markdown]
# # Genotype
#  - 15 numbers to create that face

# %%
target_gene
# Out:
# array([2.25, 3.75, 5.  , 5.  , 4.  , 3.  , 3.  , 6.  , 2.5 , 3.  , 3.5 ,
#        1.15, 1.  , 1.15, 8.  ])

# %%
m = len(target_gene)
print(m)
# Out:
# 15

# %%
def create_gene(M = m):
    return np.random.rand(m) * 10

# %%
my_gene = create_gene()
my_gene
# Out:
# array([4.25168919, 8.57634078, 5.53306219, 3.57347973, 3.08856349,
#        5.87619147, 9.77477383, 1.3748222 , 5.61603833, 5.37437186,
#        8.22684869, 4.53672754, 0.93855101, 8.83273865, 2.104717  ])

# %%
draw_face(my_gene)

# %% [markdown]
# # Fitness
#  - How sucessful the gene of the agent
#  - Euclidean Distance measures the error
#  - similarity (fitness) is the inverse of distance
#
# $$ Fitness(v) = \frac{1}{1 + dist(v, target)} $$

# %%
def fitness(v):
    error = (target_gene - v)
    return 1 / (1 + np.dot(error, error))

# %%
fitness(my_gene)
# Out:
# 0.004000713189887816

# %%
fitness(target_gene)
# Out:
# 1.0

# %% [markdown]
# # Population

# %%
N = 4
population = {i:create_gene() for i in range(N)}

# %%
population
# Out:
# {0: array([7.18170346, 8.63250338, 1.88559792, 0.5488342 , 0.01110485,
#         2.48841115, 9.16965493, 5.16562007, 3.65385176, 9.06551893,
#         0.97170132, 7.98786633, 9.7773566 , 1.12860899, 3.7145811 ]),
#  1: array([2.79985533, 3.5614226 , 9.47992817, 4.48642047, 6.05596121,
#         7.56439576, 5.81859384, 5.21384946, 3.76949808, 3.93424964,
#         4.34880189, 3.2769418 , 6.83723497, 0.88923145, 5.03141877]),
#  2: array([5.58941718, 8.86102598, 8.91395307, 8.74520078, 4.45868783,
#         0.76520158, 7.03901469, 6.65336203, 5.77241075, 2.69580762,
#         5.45709728, 1.8284415 , 9.4263306 , 3.02432801, 7.45765528]),
#  3: array([7.5183307 , 9.25698088, 7.78705892, 5.23189052, 3.586124  ,
#         5.70528426, 7.36616172, 7.08396908, 9.03470858, 2.07858998,
#         9.53001613, 4.66347766, 7.22163088, 0.93483421, 6.73417172])}

# %%
N = 10
population = {i:create_gene() for i in range(N)}

fig = plt.figure()
for i in range(10):
    plt.subplot(2, 5, i+1)
    draw_face(population[i])

# %% [markdown]
# # Selection
#  - who are the successful agents

# %%
success = {agent_id: fitness(agent_genome) for agent_id, agent_genome in population.items()}

# %%
success
# Out:
# {0: 0.007041492975128195,
#  1: 0.005083749830043548,
#  2: 0.004189491934166077,
#  3: 0.0036865589480925822,
#  4: 0.003804512264090717,
#  5: 0.005629155209195995,
#  6: 0.008666855003339396,
#  7: 0.005691739218258796,
#  8: 0.00414639775437223,
#  9: 0.0053842523822792915}

# %%
total_success = sum(success.values())
total_success
# Out:
# 0.05332420551896683

# %%
reproduction_probability = {agent_id: success[agent_id]/total_success for agent_id in success.keys()}

# %%
reproduction_probability
# Out:
# {0: 0.13205059328307506,
#  1: 0.09533662584499857,
#  2: 0.07856642013495956,
#  3: 0.06913481245925575,
#  4: 0.07134681571087814,
#  5: 0.10556472720805501,
#  6: 0.1625313479871105,
#  7: 0.10673837824427235,
#  8: 0.07775826595104923,
#  9: 0.10097201317634583}

# %%
pr = [reproduction_probability[agent_id] for agent_id in range(N)]
select = np.random.choice(N, 2, replace= False, p=pr)
select
# Out:
# array([8, 9])

# %%
def selection(population):
    success = {agent_id: fitness(agent_genome) for agent_id, agent_genome in population.items()}
    total_success = sum(success.values())
    reproduction_probability = {agent_id: success[agent_id]/total_success for agent_id in success.keys()}
    pr = [reproduction_probability[agent_id] for agent_id in range(N)]
    select = np.random.choice(N, 2, replace= False, p=pr)
    return select

# %%
selection(population)
# Out:
# array([1, 9])

# %% [markdown]
# # Crossover

# %%
parent0 = population[select[0]]
parent1 = population[select[1]]

# %%
parent0
# Out:
# array([9.50445462, 0.04593962, 6.26652608, 4.25403059, 5.92218401,
#        4.77956149, 6.26639125, 1.99672473, 9.28640102, 4.57883994,
#        6.09158284, 5.09241902, 2.94065795, 6.90473814, 2.48473035])

# %%
parent1
# Out:
# array([8.59189164, 1.85003019, 2.66656047, 9.18443845, 3.57920876,
#        6.0953459 , 0.70895211, 4.1921692 , 0.07273997, 0.57209925,
#        0.90293611, 4.21147332, 4.0962145 , 9.03341754, 8.17033162])

# %%
cut = np.random.randint(m)

child0 = np.hstack((parent0[:cut],parent1[cut:]))
child1 = np.hstack((parent1[:cut],parent0[cut:]))

# %%
child0
# Out:
# array([9.50445462, 0.04593962, 6.26652608, 4.25403059, 5.92218401,
#        4.77956149, 6.26639125, 1.99672473, 0.07273997, 0.57209925,
#        0.90293611, 4.21147332, 4.0962145 , 9.03341754, 8.17033162])

# %%
child1
# Out:
# array([8.59189164, 1.85003019, 2.66656047, 9.18443845, 3.57920876,
#        6.0953459 , 0.70895211, 4.1921692 , 9.28640102, 4.57883994,
#        6.09158284, 5.09241902, 2.94065795, 6.90473814, 2.48473035])

# %%
def crossover(selectedParents):
    parent0 = population[selectedParents[0]]
    parent1 = population[selectedParents[1]]
    
    cut = np.random.randint(m)
    child0 = np.hstack((parent0[:cut],parent1[cut:]))
    child1 = np.hstack((parent1[:cut],parent0[cut:]))
    return child0, child1

# %%
crossover(select)
# Out:
# (array([9.50445462, 0.04593962, 6.26652608, 4.25403059, 5.92218401,
#         4.77956149, 6.26639125, 1.99672473, 9.28640102, 4.57883994,
#         6.09158284, 4.21147332, 4.0962145 , 9.03341754, 8.17033162]),
#  array([8.59189164, 1.85003019, 2.66656047, 9.18443845, 3.57920876,
#         6.0953459 , 0.70895211, 4.1921692 , 0.07273997, 0.57209925,
#         0.90293611, 5.09241902, 2.94065795, 6.90473814, 2.48473035]))

# %% [markdown]
# # Mutation

# %%
def mutation(child, p = 0.05):
    mutation_point = np.random.randint(len(child))
    if np.random.rand() < p:
        child[mutation_point] = np.random.rand() * 10
    return child

# %%
mutation(child0, p = 0.995)
# Out:
# array([9.50445462, 4.61361917, 6.26652608, 4.25403059, 5.92218401,
#        4.77956149, 6.26639125, 1.99672473, 0.07273997, 0.57209925,
#        0.90293611, 4.21147332, 4.0962145 , 9.03341754, 8.17033162])

# %%
eyes = [2.25,3.75,5,5,4] 
nose = [3,3,6]
mouth = [2.5,3,3.5, 1.15,1,1.15,8]

target_gene = np.array(eyes + nose + mouth)

def draw_face(target = target_gene):
    plt.plot([target[0],target[1]], [target[2],target[3]], 'go', markersize=target[4]*10)
    plt.plot(target[5], target[6], 'r^', markersize=target[7]*10)
    plt.plot([target[8],target[9],target[10]], [target[11],target[12],target[13]], 'b', linewidth=target[14])
    plt.tight_layout()

class agent():
    def __init__(self, idx, m = 15):
        self.id = idx
        self.m = m
        self.genome = create_gene()
        
    def create_gene(self):
        return np.random.rand(self.m) * 10
    
    def fitness(self, target_gene):
        error = (target_gene - self.genome)
        return 1 / (1 + np.dot(error, error))
    
    
class evolution():
    def __init__(self, N, target_gene = target_gene): 
        self.target = target_gene
        self.population = {i:agent(i) for i in range(N)}
        
        self.success = {i: self.population[i].fitness(self.target) for i in range(N)}
        total_success = sum(self.success.values())
        
        self.reproduction_probability = {i: success[i]/total_success for i in range(N)}

    def selection():
        pr = [self.reproduction_probability[i] for i in range(N)]
        select = np.random.choice(N, 2, replace= False, p=pr)
        return select
    
    def crossover(self, selectedParents):
        parent0 = self.population[selectedParents[0]].genome
        parent1 = self.population[selectedParents[1]].genome

        cut = np.random.randint(m)
        child_gene = np.hstack((parent0[:cut],parent1[cut:]))
        return child_gene
    
    def mutation(self, child_gene, p = 0.05):
        mutation_point = np.random.randint(len(child_gene))
        if np.random.rand() < p:
            child_gene[mutation_point] = np.random.rand() * 10
        return child_gene
    
    def create_offspring(self):
        parents = self.selection()
        child_gene = self.crossover(parents)
        
        child_gene = mutation(child_gene)
        return child_gene

# %%
world = evolution(10)

# %%
world.success
# Out:
# {0: 0.005552693288447319,
#  1: 0.005414383308687761,
#  2: 0.004758031355890195,
#  3: 0.0037457879364204533,
#  4: 0.008019283417490742,
#  5: 0.008285207758560469,
#  6: 0.007345945713856664,
#  7: 0.005491924866696022,
#  8: 0.00559886519467919,
#  9: 0.00581599412602202}

# %%
world.reproduction_probability
# Out:
# {0: 0.11730324606098222,
#  1: 0.08468947698058565,
#  2: 0.069792159838807,
#  3: 0.061413869606047146,
#  4: 0.06337883739045172,
#  5: 0.09377530886590937,
#  6: 0.14437992462998478,
#  7: 0.0948178871146568,
#  8: 0.06907425992837475,
#  9: 0.08969550694488038}
