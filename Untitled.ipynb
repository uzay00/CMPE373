# %%
import time
import os

def clear_output():
    os.system('clear')
def Yaz(mytext):
    for i in range(0,len(mytext)):
        print(mytext[:i])
        time.sleep(0.1)
        clear_output()

def Egitim():
    mytext ="Televizyonda Gördüğün Kodları Anlıyor Musun?\n"
    Yaz(mytext)
    clear_output()    
    x = input("Televizyonda Gördüğün Kodları Anlıyor Musun?\n")
    print("")
    if x == "Hayırr :(":
        mytext2 = "Anlamak İster Misin?\n"
        Yaz(mytext2)
        clear_output()    
        c = input("Anlamak İster Misin?\n")
        print("")
        if c == "Evettt":
            mytext3 = "Hemen Ücretsiz YAPAY ZEKA Eğitimimize Başvur\n"
            Yaz(mytext3)
            clear_output()    
            p =  input("Hemen Ücretsiz YAPAY ZEKA Eğitimimize Başvur\n")
            print("")
            if p == "Nasıl??":
                mytext4 = "Bit.ly/yapayzeka04 Adresinden Tabiikide Çabuk Acele Et...\n"
                Yaz(mytext4)
                print("Bit.ly/yapayzeka04 Adresinden Tabiikide Çabuk Acele Et...\n")
                import matplotlib.pyplot as plt
                import matplotlib.image as mpimg
                img=mpimg.imread('kave-4poster.jpg')
                imgplot = plt.imshow(img)
                plt.show()
                print("")


Egitim()
# Out:
# T
# Te
# Tel
# Tele
# Telev
# Televi
# Televiz
# Televizy
# Televizyo
# Televizyon
# Televizyond
# Televizyonda
# Televizyonda
# Televizyonda G
# Televizyonda Gö
# Televizyonda Gör
# Televizyonda Görd
# Televizyonda Gördü
# Televizyonda Gördüğ
# Televizyonda Gördüğü
# Televizyonda Gördüğün
# Televizyonda Gördüğün
# Televizyonda Gördüğün K
# Televizyonda Gördüğün Ko
# Televizyonda Gördüğün Kod
# Televizyonda Gördüğün Kodl
# Televizyonda Gördüğün Kodla
# Televizyonda Gördüğün Kodlar
# Televizyonda Gördüğün Kodları
# Televizyonda Gördüğün Kodları
# Televizyonda Gördüğün Kodları A
# Televizyonda Gördüğün Kodları An
# Televizyonda Gördüğün Kodları Anl
# Televizyonda Gördüğün Kodları Anlı
# Televizyonda Gördüğün Kodları Anlıy
# Televizyonda Gördüğün Kodları Anlıyo
# Televizyonda Gördüğün Kodları Anlıyor
# Televizyonda Gördüğün Kodları Anlıyor
# Televizyonda Gördüğün Kodları Anlıyor M
# Televizyonda Gördüğün Kodları Anlıyor Mu
# Televizyonda Gördüğün Kodları Anlıyor Mus
# ...
